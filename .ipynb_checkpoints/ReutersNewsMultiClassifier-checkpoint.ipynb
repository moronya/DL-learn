# %%
import numpy as np
from keras.datasets import reuters
from keras import models
from keras import layers
(train_data, train_labels),(test_data, test_labels) = reuters.load_data(num_words=10000)

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %% [markdown]
# # Preparing data

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# %% [markdown]
# # Vectorize both training and test data

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results

# %%
one_hot_train_labels = to_one_hot(train_labels)
one_hot_test_labels = to_one_hot(test_labels)

# %% [markdown]
# # Building the network

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer = 'rmsprop', 
             loss = 'categorical_crossentropy',
             metrics=['accuracy'])
# lets set aside a validation set
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %% [markdown]
# # Training the model

# %%
history = model.fit(partial_x_train, 
                   partial_y_train, 
                   epochs=9,
                   batch_size=512, 
                   validation_data=(x_val, y_val))
# Out:
# Epoch 1/9
# 16/16 [==============================] - 1s 25ms/step - loss: 2.7738 - accuracy: 0.4767 - val_loss: 1.8740 - val_accuracy: 0.6170
# Epoch 2/9
# 16/16 [==============================] - 0s 19ms/step - loss: 1.5835 - accuracy: 0.6696 - val_loss: 1.4009 - val_accuracy: 0.6780
# Epoch 3/9
# 16/16 [==============================] - 0s 16ms/step - loss: 1.2102 - accuracy: 0.7342 - val_loss: 1.2017 - val_accuracy: 0.7240
# Epoch 4/9
# 16/16 [==============================] - 0s 20ms/step - loss: 0.9899 - accuracy: 0.7826 - val_loss: 1.1043 - val_accuracy: 0.7470
# Epoch 5/9
# 16/16 [==============================] - 0s 20ms/step - loss: 0.8219 - accuracy: 0.8231 - val_loss: 1.0117 - val_accuracy: 0.7790
# Epoch 6/9
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6936 - accuracy: 0.8478 - val_loss: 0.9519 - val_accuracy: 0.8060
# Epoch 7/9
# 16/16 [==============================] - 0s 16ms/step - loss: 0.5811 - accuracy: 0.8755 - val_loss: 0.9124 - val_accuracy: 0.8020
# Epoch 8/9
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4913 - accuracy: 0.8980 - val_loss: 0.8785 - val_accuracy: 0.8110
# Epoch 9/9
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4154 - accuracy: 0.9124 - val_loss: 0.8586 - val_accuracy: 0.8200

# %% [markdown]
# # Visualize loss and accuracy curves

# %%
import matplotlib.pyplot as plt
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Plotting the training and validation accuracy

# %%
plt.clf()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Testing data

# %%
results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# 71/71 [==============================] - 0s 1ms/step - loss: 0.9424 - accuracy: 0.7907
